# %% [markdown]
# __[![image.png](attachment:image.png)](http://icdss.uk)__

# %% [markdown]
# # Demo: Database for Data Science <a class="anchor" id="home"></a>
# - [Interactive Session 1: Desinging Database](#designing-database)
#     - [Diagram and Schema](#designing-database-1)
#     - [Normalisation](#designing-database-2)
# - [Interactive Session 2: Creating and Manipulating Table](#design-table)
#     - [CREATE, ALTER](#design-table-1)
#     - [INSERT, UPDATE, DELETE](#design-table-2)
# - [Interactive Session 3: Accessing Data](#query-statement)
#     - [SELECT](#query-statement-1)
#     - [JOIN](#query-statement-2)
# - [Interactive Session 4: Transaction Processing](#transaction)
# - [Interactive Session 5: Import Data in PostgreSQL](#PostgreSQL)

# %% [markdown]
# ## SQL Installation

# %% [markdown]
# Before you start the interactive session. <br>
# **Run** the following code.

# %%
# %%!
# pip install --trusted-host pypi.org ipython-sql
# Out:
# ['Collecting ipython-sql',
#  '  Downloading https://files.pythonhosted.org/packages/ab/df/427e7cf05ffc67e78672ad57dce2436c1e825129033effe6fcaf804d0c60/ipython_sql-0.3.9-py2.py3-none-any.whl',
#  'Collecting prettytable (from ipython-sql)',
#  '  Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2',
#  'Collecting sqlalchemy>=0.6.7 (from ipython-sql)',
#  '\x1b[?25l  Downloading https://files.pythonhosted.org/packages/25/c9/b0552098cee325425a61efdf380c51b5c721e459081c85bbb860f501c091/SQLAlchemy-1.2.12.tar.gz (5.6MB)',
#  '',
#  '\x1b[K    0% |                                | 10kB 18.9MB/s eta 0:00:01',
#  '\x1b[K    0% |▏                               | 20kB 24.0MB/s eta 0:00:01',
#  '\x1b[K    0% |▏                               | 30kB 19.9MB/s eta 0:00:01',
#  '\x1b[K    0% |▎                               | 40kB 6.5MB/s eta 0:00:01',
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# ## Interactive Session 1: Desinging Database <a class="anchor" id="designing-database"></a>

# %% [markdown]
# ### Diagram and Schema <a class="anchor" id="designing-database-1"></a>
# The tables show the information realated to students of Data Science Institute.<br>
# Make:
# 1. E-R Diagram
# 2. Relational Schema
#
# ![image.png](attachment:image.png)
# [Back to the top](#home)

# %%
Hint:
# Draw the ER diagram.
# What is the relation between STUDENT-QUALIFICATION and QUALIFICATION, STUDENT-QUALIFICATION and STUDENT?
# Identify the primary keys and foreign keys in each entity.
# Type your relational schema here. (Consider the data type of each attribute)

# %% [markdown]
# ### Normalisation <a class="anchor" id="designing-database-2"></a>
# Normalise the table into third normal form (3NF).
# ![image.png](attachment:image.png)
# [Back to the top](#home)

# %%
Hint:
# Construct the table in 1NF.
# Identify the prymary key and foreign key.
# Produce the tables in 2NF.
# Construct the tables in 3NF.

# %% [markdown]
# ## Interactive Session 2: Creating and Manipulating Table <a class="anchor" id="design-table"></a>

# %% [markdown]
# ### CREATE, ALTER statements <a class="anchor" id="design-table-1"></a>

# %% [markdown]
# Only **SQL syntax** are allowed to be used to recreate these tables.

# %% [markdown]
# Create the **Store Table**. (Only the header)
# ![image.png](attachment:image.png)

# %% [markdown]
# **Opening_Year** column is replaced with **Store_Type** column. (Only the header)
# <br>
# Change the table.
# ![image.png](attachment:image.png)

# %% [markdown]
# The **Employee Table** and **Profit Table** have been created for you.
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# [Back to the top](#home)

# %% [markdown]
# ### INSERT, UPDATE, DELETE statements <a class="anchor" id="design-table-2"></a>

# %% [markdown]
# Insert **all** of the data into the table.
# ![image.png](attachment:image.png)

# %% [markdown]
# A store in **Wimbeldon** has just opened recently.<br>
# Update the table.
# ![image.png](attachment:image.png)

# %% [markdown]
# Replace the row that contains **Ealing** with **Hammersmith**.
# ![image.png](attachment:image.png)
# [Back to the top](#home)

# %% [markdown]
# ## Interactive Session 3: Accessing Data <a class="anchor" id="query-statement"></a>

# %% [markdown]
# ### SELECT statement<a class="anchor" id="query-statement-1"></a>

# %% [markdown]
# Based on the *Revenue Table*, provide the following information:
# 1. Monthly Average Profit of **All** stores.
# 2. Sum of Monthly Average Revenue of **All** stores.
# 3. Store with the highest Monthly Average Revenue.
# 4. Store with the lowest Monthly Average Profit.

# %% [markdown]
# Make a table that has only stores with Average Monthly Profit >= 30,000

# %% [markdown]
# Make a new table and sort the employees by the Store_ID

# %% [markdown]
# [Back to the top](#home)

# %% [markdown]
# ### JOIN statement<a class="anchor" id="query-statement-2"></a>

# %% [markdown]
# The tables have been created for you.
# ![image.png](attachment:image.png)

# %% [markdown]
# Query 1A: Select the names and job start dates of all employees who work for the department number 5.

# %% [markdown]
# Query 1B: Select the names, job start dates, and job titles of all employees who work for the department number 5.

# %% [markdown]
# Query 2A: Perform a Left Outer Join on the EMPLOYEES and DEPARTMENT tables and select employee id, last name, department id and department name for all employees

# %% [markdown]
# Query 2B: Re-write the query for 2A to limit the result set to include only the rows for employees born before 1980.

# %% [markdown]
# Query 2C: Re-write the query for 2A to have the result set include all the employees but department names for only the employees who were born before 1980.

# %% [markdown]
# Query 3A: Perform a Full Join on the EMPLOYEES and DEPARTMENT tables and select the First name, Last name and Department name of all employees

# %% [markdown]
# Query 3B: Re-write Query 3A to have the result set include all employee names but department id and department names only for male employees.

# %% [markdown]
# [Back to the top](#home)

# %% [markdown]
# ## Interactive Session 4: Trasaction Processing  <a class="anchor" id="transaction"></a>

# %% [markdown]
# [Back to the top](#home)
