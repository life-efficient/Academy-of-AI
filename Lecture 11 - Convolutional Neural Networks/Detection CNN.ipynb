# %% [markdown]
# # Building a CNN for object detection

# %%
# IMPORTS
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader, random_split
import S40dataset
import matplotlib.pyplot as plt
import time

# HYPERPARAMETERS
batch_size = 4
epochs = 1
lr = 0.00001

# compose transforms 
# resize imgs
# convert PIL images into Torch Tensors

# MAKE DATASET
# make the dataset and pass it our transforms

# SPLIT DATASET
train_len = int( 0.8 * len(dataset))
val_len = int( 0.1 * len(dataset))
test_len = len(dataset) - train_len - val_len
# split the dataset into train, test, validation

# MAKE DATALOADERS
# make the training dataloader
# make the test dataloader

# SHOW A RANDOM EXAMPLE FROM THE DATASET
for i in test_loader:
    b = i
    break
import numpy as np
idx = np.random.randint(len(test_loader))
S40dataset.show(b)

# SET NUMBER OF FILTERS TO USE IN EACH CONV LAYER
channels1 = 128
channels2 = 64
channels3 = 64
channels4 = 64

# CREATE MODEL
# create class
    # initialise
        # initialise parent class
        # make sequential model for conv layers
            # make layers

        # make sequential model for fully connected (linear) layers
            # make layers

    # define forward pass
        # forward pass through conv layers
        # flatten conv output to pass to fully connected layers
        # pass through fc layers
        # return output
        
# create instance of model
# define loss function
# define optimiser

# TRAIN
def train(model):

    train_losses = []
    for epoch in range(epochs):
        for batch_idx, batch in enumerate(train_loader):
            # unpack batch
            # forward pass
            print('label:', bndbox, 'prediction:', pred_bndbox)
            # compute loss for this batch
            # zero gradients of optimiser
            # backward pass (find rate of change of loss with respect to model parameters)
            # take optimisation step
            print('Epoch:', epoch, 'Batch:', batch_idx, 'Loss:', loss.item())
            train_losses.append(loss.item())    #append loss for this batch to list of all losses
            if batch_idx == 200:    # tell your model to stop at some batch_idx if you want
                #break
                pass

train(cnn)
# save model

def test(model):
    # set in evaluation mode
    for idx, batch in enumerate(test_loader):
        print(type(batch))
        # unpack batch
        # forward pass
        S40dataset.show(batch, pred_bndbox=pred_bndbox)
        if idx == 10:
            break


test(cnn)
